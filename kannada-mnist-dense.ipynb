# %% [markdown]
# ### Multiclass classification models using neural networks
# Data:<br>https://www.kaggle.com/competitions/Kannada-MNIST
#
# ### Densely connected network

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
random_state = 42
np.random.seed(random_state)
tf.random.set_seed(random_state)
import time
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
# load data
train = pd.read_csv('drive/MyDrive/input/Kannada-MNIST/train.csv')
test = pd.read_csv('drive/MyDrive/input/Kannada-MNIST/test.csv', index_col='id')
sample_submission = pd.read_csv('drive/MyDrive/input/Kannada-MNIST/sample_submission.csv')

# define X_train, y_train, and X_test
X_train = train.drop('label', axis=1)
y_train = train['label']
X_test = test

# normalize data from 0 to 1
X_train = X_train.astype(float)/255.
X_test = X_test.astype(float)/255.

# reshape data
X_train = X_train.to_numpy().reshape(-1, 28, 28, 1)
X_test = X_test.to_numpy().reshape(-1, 28, 28, 1)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}, X_test: {X_test.shape}')
# Out:
# X_train: (60000, 28, 28, 1), y_train: (60000, 10), X_test: (5000, 28, 28, 1)

# %%
# construct model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(2500, activation='relu'),
    # tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2000, activation='relu'),
    # tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1500, activation='relu'),
    # tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 2500)              1962500
# _________________________________________________________________
# dense_1 (Dense)              (None, 2000)              5002000
# _________________________________________________________________
# dense_2 (Dense)              (None, 1500)              3001500
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              1501000
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 11,972,510
# Trainable params: 11,972,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train val split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state=random_state) 
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}, X_val: {X_val.shape}, y_val: {y_val.shape}')
# Out:
# X_train: (48000, 28, 28, 1), y_train: (48000, 10), X_val: (12000, 28, 28, 1), y_val: (12000, 10)

# %%
# early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30, verbose=1, restore_best_weights=True)
# reduce learning rate on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=0.0001)

# optimizer
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.002,)
# optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001,)

# compile model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
# image augmentation, generate batches of image data
batch_size = 1024
datagen_train = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=10,
                                                                width_shift_range=0.2,
                                                                height_shift_range=0.2,
                                                                zoom_range=0.2,)
datagen_val = tf.keras.preprocessing.image.ImageDataGenerator()

# %%
# fit model, get fit time
start_time = time.time()
history = model.fit(datagen_train.flow(X_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(X_train)//batch_size,
                    epochs=500,
                    validation_data=(X_val, y_val),
                    validation_steps=50,
                    callbacks=[reduce_lr, es],
                    verbose=2)
print(f'fit time: {time.time()-start_time:.2f} seconds')
# Out:
# Epoch 1/500
# 46/46 - 13s - loss: 2.2026 - accuracy: 0.2895 - val_loss: 1.0990 - val_accuracy: 0.6785
# Epoch 2/500
# 46/46 - 10s - loss: 0.9147 - accuracy: 0.6806 - val_loss: 0.5019 - val_accuracy: 0.8266
# Epoch 3/500
# 46/46 - 10s - loss: 0.4609 - accuracy: 0.8457 - val_loss: 0.2179 - val_accuracy: 0.9231
# Epoch 4/500
# 46/46 - 10s - loss: 0.3097 - accuracy: 0.9011 - val_loss: 0.1215 - val_accuracy: 0.9632
# Epoch 5/500
# 46/46 - 10s - loss: 0.2308 - accuracy: 0.9280 - val_loss: 0.0777 - val_accuracy: 0.9758
# Epoch 6/500
# 46/46 - 10s - loss: 0.2070 - accuracy: 0.9363 - val_loss: 0.0768 - val_accuracy: 0.9749
# Epoch 7/500
# 46/46 - 9s - loss: 0.1711 - accuracy: 0.9465 - val_loss: 0.1312 - val_accuracy: 0.9605
# Epoch 8/500
# 46/46 - 9s - loss: 0.1582 - accuracy: 0.9510 - val_loss: 0.0896 - val_accuracy: 0.9712
# Epoch 9/500
# 46/46 - 9s - loss: 0.1420 - accuracy: 0.9557 - val_loss: 0.0707 - val_accuracy: 0.9808
# Epoch 10/500
# 46/46 - 10s - loss: 0.1367 - accuracy: 0.9588 - val_loss: 0.0539 - val_accuracy: 0.9852
# Epoch 11/500
# 46/46 - 10s - loss: 0.1271 - accuracy: 0.9621 - val_loss: 0.0731 - val_accuracy: 0.9782
# Epoch 12/500
# 46/46 - 9s - loss: 0.1207 - accuracy: 0.9629 - val_loss: 0.1076 - val_accuracy: 0.9678
# Epoch 13/500
# 46/46 - 9s - loss: 0.1173 - accuracy: 0.9643 - val_loss: 0.0549 - val_accuracy: 0.9828
# Epoch 14/500
# 46/46 - 9s - loss: 0.1094 - accuracy: 0.9672 - val_loss: 0.0551 - val_accuracy: 0.9830
# Epoch 15/500
# 46/46 - 10s - loss: 0.1049 - accuracy: 0.9679 - val_loss: 0.0548 - val_accuracy: 0.9857
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/500
# 46/46 - 10s - loss: 0.0765 - accuracy: 0.9760 - val_loss: 0.0400 - val_accuracy: 0.9873
# Epoch 17/500
# 46/46 - 9s - loss: 0.0724 - accuracy: 0.9777 - val_loss: 0.0442 - val_accuracy: 0.9852
# Epoch 18/500
# 46/46 - 9s - loss: 0.0710 - accuracy: 0.9783 - val_loss: 0.0451 - val_accuracy: 0.9871
# Epoch 19/500
# 46/46 - 9s - loss: 0.0707 - accuracy: 0.9780 - val_loss: 0.0480 - val_accuracy: 0.9858
# Epoch 20/500
# 46/46 - 10s - loss: 0.0644 - accuracy: 0.9798 - val_loss: 0.0364 - val_accuracy: 0.9896
# Epoch 21/500
# 46/46 - 9s - loss: 0.0632 - accuracy: 0.9803 - val_loss: 0.0428 - val_accuracy: 0.9890
# Epoch 22/500
# 46/46 - 9s - loss: 0.0625 - accuracy: 0.9806 - val_loss: 0.0402 - val_accuracy: 0.9887
# Epoch 23/500
# 46/46 - 10s - loss: 0.0634 - accuracy: 0.9808 - val_loss: 0.0393 - val_accuracy: 0.9902
# Epoch 24/500
# 46/46 - 10s - loss: 0.0636 - accuracy: 0.9803 - val_loss: 0.0429 - val_accuracy: 0.9889
# Epoch 25/500
# 46/46 - 10s - loss: 0.0628 - accuracy: 0.9807 - val_loss: 0.0395 - val_accuracy: 0.9895
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch
# Epoch 112/500
# 46/46 - 10s - loss: 0.0293 - accuracy: 0.9906 - val_loss: 0.0279 - val_accuracy: 0.9934
# Epoch 113/500
# 46/46 - 10s - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.0258 - val_accuracy: 0.9930
# Epoch 114/500
# 46/46 - 10s - loss: 0.0313 - accuracy: 0.9901 - val_loss: 0.0282 - val_accuracy: 0.9924
# Epoch 115/500
# 46/46 - 10s - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.0281 - val_accuracy: 0.9930
# Epoch 116/500
# 46/46 - 10s - loss: 0.0302 - accuracy: 0.9900 - val_loss: 0.0230 - val_accuracy: 0.9940
# Epoch 117/500
# 46/46 - 9s - loss: 0.0306 - accuracy: 0.9904 - val_loss: 0.0301 - val_accuracy: 0.9933
# Epoch 118/500
# 46/46 - 10s - loss: 0.0308 - accuracy: 0.9906 - val_loss: 0.0244 - val_accuracy: 0.9938
# Epoch 119/500
# 46/46 - 10s - loss: 0.0287 - accuracy: 0.9907 - val_loss: 0.0272 - val_accuracy: 0.9937
# Epoch 120/500
# 46/46 - 10s - loss: 0.0296 - accuracy: 0.9908 - val_loss: 0.0210 - val_accuracy: 0.9940
# Epoch 121/500
# 46/46 - 10s - loss: 0.0313 - accuracy: 0.9903 - val_loss: 0.0266 - val_accuracy: 0.9928
# Epoch 122/500
# 46/46 - 10s - loss: 0.0294 - accuracy: 0.9905 - val_loss: 0.0260 - val_accuracy: 0.9934
# Epoch 123/500
# 46/46 - 10s - loss: 0.0296 - accuracy: 0.9908 - val_loss: 0.0313 - val_accuracy: 0.9928
# Epoch 124/500
# 46/46 - 10s - loss: 0.0291 - accuracy: 0.9905 - val_loss: 0.0269 - val_accuracy: 0.9933
# Epoch 125/500
# 46/46 - 10s - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.0252 - val_accuracy: 0.9937
# Epoch 126/500
# 46/46 - 10s - loss: 0.0302 - accuracy: 0.9908 - val_loss: 0.0280 - val_accuracy: 0.9932
# Epoch 127/500
# 46/46 - 10s - loss: 0.0296 - accuracy: 0.9904 - val_loss: 0.0249 - val_accuracy: 0.9933
# Epoch 128/500
# 46/46 - 10s - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.0259 - val_accuracy: 0.9935
# Epoch 129/500
# 46/46 - 9s - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.0269 - val_accuracy: 0.9937
# Epoch 130/500
# 46/46 - 10s - loss: 0.0288 - accuracy: 0.9914 - val_loss: 0.0254 - val_accuracy: 0.9935
# Epoch 131/500
# 46/46 - 10s - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.0265 - val_accuracy: 0.9937
# Epoch 132/500
# 46/46 - 10s - loss: 0.0298 - accuracy: 0.9909 - val_loss: 0.0267 - val_accuracy: 0.9933
# Epoch 133/500
# 46/46 - 10s - loss: 0.0305 - accuracy: 0.9903 - val_loss: 0.0277 - val_accuracy: 0.9930
# Epoch 134/500
# 46/46 - 9s - loss: 0.0304 - accuracy: 0.9909 - val_loss: 0.0235 - val_accuracy: 0.9933
# Epoch 135/500
# 46/46 - 10s - loss: 0.0283 - accuracy: 0.9913 - val_loss: 0.0267 - val_accuracy: 0.9938
# Epoch 136/500
# 46/46 - 9s - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.0268 - val_accuracy: 0.9937
# Epoch 137/500
# 46/46 - 9s - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.0228 - val_accuracy: 0.9935
# Epoch 138/500
# 46/46 - 9s - loss: 0.0268 - accuracy: 0.9911 - val_loss: 0.0246 - val_accuracy: 0.9937
# Epoch 139/500
# 46/46 - 9s - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.0230 - val_accuracy: 0.9941
# Epoch 140/500
# 46/46 - 9s - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.0227 - val_accuracy: 0.9936
# Epoch 141/500
# 46/46 - 9s - loss: 0.0275 - accuracy: 0.9915 - val_loss: 0.0223 - val_accuracy: 0.9942
# Epoch 142/500
# 46/46 - 9s - loss: 0.0275 - accuracy: 0.9914 - val_loss: 0.0251 - val_accuracy: 0.9938
# Epoch 143/500
# 46/46 - 9s - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.0243 - val_accuracy: 0.9933
# Epoch 144/500
# 46/46 - 10s - loss: 0.0292 - accuracy: 0.9911 - val_loss: 0.0236 - val_accuracy: 0.9937
# Epoch 145/500
# 46/46 - 9s - loss: 0.0298 - accuracy: 0.9911 - val_loss: 0.0218 - val_accuracy: 0.9937
# Epoch 146/500
# 46/46 - 9s - loss: 0.0291 - accuracy: 0.9906 - val_loss: 0.0225 - val_accuracy: 0.9940
# Epoch 147/500
# 46/46 - 9s - loss: 0.0282 - accuracy: 0.9909 - val_loss: 0.0221 - val_accuracy: 0.9944
# Epoch 148/500
# 46/46 - 9s - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.0225 - val_accuracy: 0.9941
# Epoch 149/500
# 46/46 - 9s - loss: 0.0290 - accuracy: 0.9903 - val_loss: 0.0276 - val_accuracy: 0.9935
# Epoch 150/500
# 46/46 - 9s - loss: 0.0286 - accuracy: 0.9915 - val_loss: 0.0217 - val_accuracy: 0.9937
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# fit time: 1461.71 seconds

# %%
# evaluate predictions
y_pred = np.argmax(model.predict(X_test), axis=1)
submission = sample_submission.copy()
submission['label'] = y_pred
submission.head()
# Out:
#    id  label
# 0   0      3
# 1   1      0
# 2   2      2
# 3   3      6
# 4   4      7

# %%
submission.to_csv('drive/MyDrive/submission.csv', index=False)

# %%
model.save('drive/MyDrive/model_grad_imaug_v2')
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/model_grad_imaug_v2/assets
