# %% [markdown]
# ### Multiclass classification models using neural networks
# Data:<br>https://www.kaggle.com/competitions/Kannada-MNIST
#
# ### CNN

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
random_state = 42
np.random.seed(random_state)
tf.random.set_seed(random_state)
import time
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
# load data
train = pd.read_csv('drive/MyDrive/input/Kannada-MNIST/train.csv')
test = pd.read_csv('drive/MyDrive/input/Kannada-MNIST/test.csv', index_col='id')
sample_submission = pd.read_csv('drive/MyDrive/input/Kannada-MNIST/sample_submission.csv')

# define X_train, y_train, and X_test
X_train = train.drop('label', axis=1)
y_train = train['label']
X_test = test

# normalize data from 0 to 1
X_train = X_train.astype(float)/255.
X_test = X_test.astype(float)/255.

# reshape data
X_train = X_train.to_numpy().reshape(-1, 28, 28, 1)
X_test = X_test.to_numpy().reshape(-1, 28, 28, 1)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}, X_test: {X_test.shape}')
# Out:
# X_train: (60000, 28, 28, 1), y_train: (60000, 10), X_test: (5000, 28, 28, 1)

# %%
# construct model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), padding='same', activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Flatten(),    
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 32)          18464
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               73984
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 268,330
# Trainable params: 267,146
# Non-trainable params: 1,184
# _________________________________________________________________

# %%
# train val split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state=random_state) 
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}, X_val: {X_val.shape}, y_val: {y_val.shape}')
# Out:
# X_train: (48000, 28, 28, 1), y_train: (48000, 10), X_val: (12000, 28, 28, 1), y_val: (12000, 10)

# %%
# early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, verbose=1, restore_best_weights=True)
# reduce learning rate on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=0.0001)

# optimizer
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.002,)
# optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001,)

# compile model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
# image augmentation, generate batches of image data
batch_size = 1024
datagen_train = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=10,
                                                                width_shift_range=0.2,
                                                                height_shift_range=0.2,
                                                                zoom_range=0.2,)
datagen_val = tf.keras.preprocessing.image.ImageDataGenerator()

# %%
# fit model, get fit time
start_time = time.time()
history = model.fit(datagen_train.flow(X_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(X_train)//batch_size,
                    epochs=500,
                    validation_data=(X_val, y_val),
                    validation_steps=50,
                    callbacks=[reduce_lr, es],
                    verbose=2)
print(f'fit time: {time.time()-start_time:.2f} seconds')
# Out:
# Epoch 1/500
# 46/46 - 42s - loss: 0.6237 - accuracy: 0.7953 - val_loss: 2.7448 - val_accuracy: 0.1083
# Epoch 2/500
# 46/46 - 10s - loss: 0.1235 - accuracy: 0.9606 - val_loss: 3.9531 - val_accuracy: 0.1018
# Epoch 3/500
# 46/46 - 10s - loss: 0.0780 - accuracy: 0.9752 - val_loss: 3.5160 - val_accuracy: 0.1048
# Epoch 4/500
# 46/46 - 10s - loss: 0.0609 - accuracy: 0.9813 - val_loss: 2.9129 - val_accuracy: 0.2848
# Epoch 5/500
# 46/46 - 10s - loss: 0.0501 - accuracy: 0.9845 - val_loss: 2.8222 - val_accuracy: 0.3063
# Epoch 6/500
# 46/46 - 10s - loss: 0.0445 - accuracy: 0.9858 - val_loss: 2.1309 - val_accuracy: 0.5008
# Epoch 7/500
# 46/46 - 10s - loss: 0.0386 - accuracy: 0.9879 - val_loss: 2.1520 - val_accuracy: 0.4408
# Epoch 8/500
# 46/46 - 10s - loss: 0.0361 - accuracy: 0.9888 - val_loss: 1.8984 - val_accuracy: 0.4930
# Epoch 9/500
# 46/46 - 10s - loss: 0.0349 - accuracy: 0.9890 - val_loss: 1.1057 - val_accuracy: 0.7426
# Epoch 10/500
# 46/46 - 10s - loss: 0.0305 - accuracy: 0.9909 - val_loss: 0.4296 - val_accuracy: 0.8743
# Epoch 11/500
# 46/46 - 10s - loss: 0.0297 - accuracy: 0.9907 - val_loss: 0.1428 - val_accuracy: 0.9551
# Epoch 12/500
# 46/46 - 10s - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.0406 - val_accuracy: 0.9872
# Epoch 13/500
# 46/46 - 10s - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0868 - val_accuracy: 0.9732
# Epoch 14/500
# 46/46 - 10s - loss: 0.0271 - accuracy: 0.9914 - val_loss: 0.0239 - val_accuracy: 0.9924
# Epoch 15/500
# 46/46 - 10s - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.0211 - val_accuracy: 0.9942
# Epoch 16/500
# 46/46 - 10s - loss: 0.0246 - accuracy: 0.9917 - val_loss: 0.0156 - val_accuracy: 0.9944
# Epoch 17/500
# 46/46 - 10s - loss: 0.0243 - accuracy: 0.9922 - val_loss: 0.0727 - val_accuracy: 0.9748
# Epoch 18/500
# 46/46 - 10s - loss: 0.0226 - accuracy: 0.9931 - val_loss: 0.0604 - val_accuracy: 0.9778
# Epoch 19/500
# 46/46 - 10s - loss: 0.0210 - accuracy: 0.9936 - val_loss: 0.0202 - val_accuracy: 0.9946
# Epoch 20/500
# 46/46 - 10s - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.0166 - val_accuracy: 0.9949
# Epoch 21/500
# 46/46 - 10s - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.0151 - val_accuracy: 0.9959
# Epoch 22/500
# 46/46 - 10s - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.0138 - val_accuracy: 0.9960
# Epoch 23/500
# 46/46 - 10s - loss: 0.0210 - accuracy: 0.9932 - val_loss: 0.0156 - val_accuracy: 0.9952
# Epoch 24/500
# 46/46 - 10s - loss: 0.0210 - accuracy: 0.9935 - val_loss: 0.0113 - val_accuracy: 0.9967
# Epoch 25/500
# 46/46 - 10s - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0108 - val_accuracy: 0.9968
# Epoch 26/500
# 46/46 - 10s - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0097 - val_accuracy: 0.9971
# Epoch 27/500
# 46/46 - 10s - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.0225 - val_accuracy: 0.9935
# Epoch 28/500
# 46/46 - 10s - loss: 0.0181 - accuracy: 0.9943 - val_loss: 0.0134 - val_accuracy: 0.9959
# Epoch 29/500
# 46/46 - 10s - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0107 - val_accuracy: 0.9967
# Epoch 30/500
# 46/46 - 10s - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.0169 - val_accuracy: 0.9944
# Epoch 31/500
# 46/46 - 10s - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.0111 - val_accuracy: 0.9965
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/500
# 46/46 - 10s - loss: 0.0154 - accuracy: 0.9951 - val_loss: 0.0109 - val_accuracy: 0.9967
# Epoch 33/500
# 46/46 - 10s - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.0076 - val_accuracy: 0.9978
# Epoch 34/500
# 46/46 - 10s - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.0079 - val_accuracy: 0.9977
# Epoch 35/500
# 46/46 - 10s - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0077 - val_accuracy: 0.9977
# Epoch 36/500
# 46/46 - 10s - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0123 - val_accuracy: 0.9965
# Epoch 37/500
# 46/46 - 10s - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0091 - val_accuracy: 0.9969
# Epoch 38/500
# 46/46 - 10s - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0098 - val_accuracy: 0.9969
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 39/500
# 46/46 - 10s - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0091 - val_accuracy: 0.9971
# Epoch 40/500
# 46/46 - 10s - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0092 - val_accuracy: 0.9971
# Epoch 41/500
# 46/46 - 10s - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.0094 - val_accuracy: 0.9973
# Epoch 42/500
# 46/46 - 10s - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0097 - val_accuracy: 0.9971
# Epoch 43/500
# 46/46 - 10s - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0084 - val_accuracy: 0.9973
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 44/500
# 46/46 - 10s - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0072 - val_accuracy: 0.9976
# Epoch 45/500
# 46/46 - 10s - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.0082 - val_accuracy: 0.9973
# Epoch 46/500
# 46/46 - 10s - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0077 - val_accuracy: 0.9973
# Epoch 47/500
# 46/46 - 10s - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0072 - val_accuracy: 0.9978
# Epoch 48/500
# 46/46 - 10s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0084 - val_accuracy: 0.9971
# Epoch 49/500
# 46/46 - 10s - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0071 - val_accuracy: 0.9975
# Epoch 50/500
# 46/46 - 10s - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.0076 - val_accuracy: 0.9973
# Epoch 51/500
# 46/46 - 10s - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.0073 - val_accuracy: 0.9974
# Epoch 52/500
# 46/46 - 10s - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0071 - val_accuracy: 0.9976
# Epoch 53/500
# 46/46 - 10s - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0069 - val_accuracy: 0.9976
# Epoch 54/500
# 46/46 - 10s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0065 - val_accuracy: 0.9976
# Epoch 55/500
# 46/46 - 10s - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0079 - val_accuracy: 0.9967
# Epoch 56/500
# 46/46 - 10s - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0085 - val_accuracy: 0.9973
# Epoch 57/500
# 46/46 - 10s - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0073 - val_accuracy: 0.9976
# Epoch 58/500
# 46/46 - 10s - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0075 - val_accuracy: 0.9973
# Epoch 59/500
# 46/46 - 10s - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0072 - val_accuracy: 0.9977
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 60/500
# 46/46 - 10s - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0080 - val_accuracy: 0.9973
# Epoch 61/500
# 46/46 - 10s - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0072 - val_accuracy: 0.9975
# Epoch 62/500
# 46/46 - 10s - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0067 - val_accuracy: 0.9978
# Epoch 63/500
# 46/46 - 10s - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0067 - val_accuracy: 0.9977
# Epoch 64/500
# 46/46 - 10s - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0068 - val_accuracy: 0.9978
# Epoch 65/500
# 46/46 - 10s - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0061 - val_accuracy: 0.9982
# Epoch 66/500
# 46/46 - 10s - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0068 - val_accuracy: 0.9978
# Epoch 67/500
# 46/46 - 10s - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0074 - val_accuracy: 0.9977
# Epoch 68/500
# 46/46 - 10s - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0068 - val_accuracy: 0.9978
# Epoch 69/500
# 46/46 - 10s - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0070 - val_accuracy: 0.9975
# Epoch 70/500
# 46/46 - 10s - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0074 - val_accuracy: 0.9973
# Epoch 71/500
# 46/46 - 10s - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0065 - val_accuracy: 0.9979
# Epoch 72/500
# 46/46 - 10s - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0061 - val_accuracy: 0.9981
# Epoch 73/500
# 46/46 - 10s - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0068 - val_accuracy: 0.9978
# Epoch 74/500
# 46/46 - 10s - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0075 - val_accuracy: 0.9972
# Epoch 75/500
# 46/46 - 10s - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0070 - val_accuracy: 0.9975
# Epoch 76/500
# 46/46 - 10s - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0076 - val_accuracy: 0.9976
# Epoch 77/500
# 46/46 - 10s - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0079 - val_accuracy: 0.9973
# Epoch 78/500
# 46/46 - 10s - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0072 - val_accuracy: 0.9977
# Epoch 79/500
# 46/46 - 10s - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0068 - val_accuracy: 0.9977
# Epoch 80/500
# 46/46 - 10s - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0072 - val_accuracy: 0.9974
# Epoch 81/500
# 46/46 - 10s - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.0072 - val_accuracy: 0.9973
# Epoch 82/500
# 46/46 - 10s - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0064 - val_accuracy: 0.9980
# Epoch 83/500
# 46/46 - 10s - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0072 - val_accuracy: 0.9976
# Epoch 84/500
# 46/46 - 10s - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0076 - val_accuracy: 0.9975
# Epoch 85/500
# 46/46 - 10s - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0070 - val_accuracy: 0.9975
# Epoch 86/500
# 46/46 - 10s - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0073 - val_accuracy: 0.9975
# Epoch 87/500
# 46/46 - 10s - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0069 - val_accuracy: 0.9978
# Epoch 88/500
# 46/46 - 10s - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0082 - val_accuracy: 0.9971
# Epoch 89/500
# 46/46 - 10s - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0075 - val_accuracy: 0.9974
# Epoch 90/500
# 46/46 - 10s - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0068 - val_accuracy: 0.9983
# Epoch 91/500
# 46/46 - 10s - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0083 - val_accuracy: 0.9973
# Epoch 92/500
# 46/46 - 10s - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0083 - val_accuracy: 0.9973
# Epoch 93/500
# 46/46 - 10s - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0067 - val_accuracy: 0.9980
# Epoch 94/500
# 46/46 - 10s - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 95/500
# 46/46 - 10s - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0065 - val_accuracy: 0.9979
# Epoch 96/500
# 46/46 - 10s - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0075 - val_accuracy: 0.9975
# Epoch 97/500
# 46/46 - 10s - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0064 - val_accuracy: 0.9980
# Epoch 98/500
# 46/46 - 10s - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0069 - val_accuracy: 0.9978
# Epoch 99/500
# 46/46 - 10s - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0066 - val_accuracy: 0.9980
# Epoch 100/500
# 46/46 - 10s - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0083 - val_accuracy: 0.9975
# Epoch 101/500
# 46/46 - 10s - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0069 - val_accuracy: 0.9977
# Epoch 102/500
# 46/46 - 10s - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0063 - val_accuracy: 0.9981
# Epoch 103/500
# 46/46 - 10s - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0082 - val_accuracy: 0.9975
# Epoch 104/500
# 46/46 - 10s - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0064 - val_accuracy: 0.9982
# Epoch 105/500
# 46/46 - 10s - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0062 - val_accuracy: 0.9982
# Epoch 106/500
# 46/46 - 10s - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0069 - val_accuracy: 0.9978
# Epoch 107/500
# 46/46 - 10s - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0069 - val_accuracy: 0.9978
# Epoch 108/500
# 46/46 - 10s - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0067 - val_accuracy: 0.9980
# Epoch 109/500
# 46/46 - 10s - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0075 - val_accuracy: 0.9977
# Epoch 110/500
# 46/46 - 10s - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0073 - val_accuracy: 0.9979
# Epoch 111/500
# 46/46 - 10s - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0076 - val_accuracy: 0.9977
# Epoch 112/500
# 46/46 - 10s - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0065 - val_accuracy: 0.9981
# Epoch 113/500
# 46/46 - 10s - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0066 - val_accuracy: 0.9981
# Epoch 114/500
# 46/46 - 10s - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0081 - val_accuracy: 0.9973
# Epoch 115/500
# 46/46 - 10s - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0151 - val_accuracy: 0.9948
# Epoch 116/500
# 46/46 - 10s - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0070 - val_accuracy: 0.9978
# Epoch 117/500
# 46/46 - 10s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0082 - val_accuracy: 0.9976
# Epoch 118/500
# 46/46 - 10s - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0090 - val_accuracy: 0.9970
# Epoch 119/500
# 46/46 - 10s - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0091 - val_accuracy: 0.9971
# Epoch 120/500
# 46/46 - 10s - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0084 - val_accuracy: 0.9972
# Epoch 121/500
# 46/46 - 10s - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0075 - val_accuracy: 0.9977
# Epoch 122/500
# 46/46 - 10s - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0075 - val_accuracy: 0.9978
# Restoring model weights from the end of the best epoch.
# Epoch 00122: early stopping
# fit time: 1236.82 seconds

# %%
# evaluate predictions
y_pred = np.argmax(model.predict(X_test), axis=1)
submission = sample_submission.copy()
submission['label'] = y_pred
submission.head()
# Out:
#    id  label
# 0   0      3
# 1   1      0
# 2   2      2
# 3   3      6
# 4   4      7

# %%
submission.to_csv('drive/MyDrive/submission.csv', index=False)

# %%
model.save('drive/MyDrive/model_conv_imaug_v1')
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/model_conv_imaug_v1/assets
